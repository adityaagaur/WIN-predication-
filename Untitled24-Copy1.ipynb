# %%
import os 
import pandas as pd 
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Aditya'

# %%
os.chdir('C:\\Users\\Aditya')

# %%
win=pd.read_excel("C:/Users/Aditya/Downloads/Win_Prediction_Data.xlsx",parse_dates=["Deal Date"])
win
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost Deal Status Code
# 0          Ekta Zutshi  Gopa Trilochana  150000.000              Won
# ...

# %%
win["Client Category"].value_counts()
# Out:
# Others                   1763
# Internal                 1454
# Services_based           1202
# Tech                      913
# Domestic Public Bank      419
# International Bank        376
# Consulting                352
# Finance                   339
# Telecom                   327
# Power ind                 264
# Domestic Private Bank     262
# Insurance                 247
# Consumer Good             185
# Automobiles               178
# Infrastructure            152
# Domestic Bank             134
# Retail_market             126
# Govt                      121
# Hospitality               119
# Manufacturing             117
# Pharma                    110
# Healthcare                 99
# Electronics                81
# Media_Journal              71
# Industries                 66
# Research Development       63
# Energy                     57
# Knowledge                  50
# Management                 43
# Govt Bank Special          41
# Payment                    40
# ...

# %%
win.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10061 entries, 0 to 10060
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Client Category   9982 non-null   object
#  1   Solution Type     10061 non-null  object
#  2   Deal Date         10061 non-null  datetime64[ns]
#  3   Sector            10061 non-null  object
#  4   Location          10061 non-null  object
#  5   VP Name           10061 non-null  object
#  6   Manager Name      10061 non-null  object
#  7   Deal Cost         10061 non-null  float64
#  8   Deal Status Code  10061 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(7)
# memory usage: 707.5+ KB

# %%
win["Deal Cost"].value_counts()
# Out:
# 294117.650     508
# 588235.290     390
# 441176.470     377
# 147058.820     363
# 0.000          246
#               ...
# 7004117.650      1
# 331470.590       1
# 193235.290       1
# 770882.350       1
# 414705.880       1
# Name: Deal Cost, Length: 1469, dtype: int64

# %%
win["Solution Type"].value_counts()
# Out:
# Solution 32    1439
# Solution 9     1418
# Solution 10    1016
# Solution 39     585
# Solution 67     584
#                ...
# Solution 60       1
# Solution 57       1
# Solution 19       1
# Solution 18       1
# Solution 56       1
# Name: Solution Type, Length: 67, dtype: int64

# %%
win["Solution Type"]
# Out:
# 0         Solution 7
# 1         Solution 7
# 2        Solution 59
# 3        Solution 59
# 4        Solution 32
#             ...
# 10056     Solution 9
# 10057     Solution 6
# 10058     Solution 9
# 10059    Solution 62
# 10060     Solution 9
# Name: Solution Type, Length: 10061, dtype: object

# %%
win.dtypes
# Out:
# Client Category             object
# Solution Type               object
# Deal Date           datetime64[ns]
# Sector                      object
# Location                    object
# VP Name                     object
# Manager Name                object
# Deal Cost                  float64
# Deal Status Code            object
# dtype: object

# %%
win['year']=win['Deal Date'].dt.year
win['year']
# Out:
# 0        2012
# 1        2012
# 2        2011
# 3        2011
# 4        2011
#          ...
# 10056    2019
# 10057    2019
# 10058    2019
# 10059    2019
# 10060    2019
# Name: year, Length: 10061, dtype: int64

# %%
#2
max_deal_year=win.groupby(['year','Client Category']).agg(count_of_deal=('Client Category','count'),
                                                           mean_of_deal=('Deal Cost','mean')).reset_index()
max_deal_year
# Out:
#      year        Client Category  count_of_deal  mean_of_deal
# 0    2011             Consulting              2    617647.055
# 1    2011          Consumer Good              3    379901.960
# 2    2011          Domestic Bank              1    588235.290
# 3    2011  Domestic Private Bank              2     66176.470
# 4    2011   Domestic Public Bank              2   2613823.530
# ..    ...                    ...            ...           ...
# 317  2019   Research Development              2    382352.940
# 318  2019          Retail_market              3    356862.747
# 319  2019         Services_based             29    542890.467
# 320  2019                   Tech             31    419079.697
# 321  2019                Telecom              3    568627.450
#
# [322 rows x 4 columns]

# %%
max_deal_year.sort_values(by='count_of_deal',ascending=False)
# Out:
#      year    Client Category  count_of_deal  mean_of_deal
# 272  2018           Internal            306   1636155.326
# 162  2015             Others            299    462791.659
# 280  2018             Others            298    693503.751
# 201  2016             Others            282    666563.413
# 241  2017             Others            272    897922.794
# ..    ...                ...            ...           ...
# 52   2012       Share_market              1    147058.820
# 53   2012          Tax_audit              1    397058.820
# 78   2013          Logistics              1     44117.650
# 76   2013  International Org              1    470588.240
# 249  2017       Share_market              1    147058.820
#
# [322 rows x 4 columns]

# %%
max_ind_deal = pd.DataFrame(win.groupby(["Client Category"])["Deal Cost"].sum().reset_index(name='deal_cost'))
max_ind_deal= max_ind_deal.sort_values('deal_cost', ascending=False)
max_ind_deal
# Out:
#           Client Category      deal_cost
# 19               Internal 1481759118.370
# 28                 Others 1089370589.020
# 35         Services_based  657495000.500
# 38                   Tech  556006765.180
# 39                Telecom  430811176.670
# 6    Domestic Public Bank  403643529.550
# 2              Consulting  370720294.280
# 20     International Bank  300861176.650
# 18              Insurance  290900294.280
# 31              Power ind  275611764.780
# 4           Domestic Bank  224152941.200
# 5   Domestic Private Bank  214348235.440
# 10                Finance  171241470.760
# 3           Consumer Good  136501176.520
# 1             Automobiles  114572353.090
# 17         Infrastructure  105689411.830
# 30                 Pharma   96374705.930
# 11                   Govt   95982352.930
# 25          Manufacturing   78900294.130
# 34          Retail_market   68634117.700
# 8                  Energy   66733235.330
# 7             Electronics   46015000.080
# ...

# %%
#3
max_deal_year=win.groupby(['Client Category']).agg(mean_of_deal=('Deal Cost','mean')).reset_index()
max_deal_year
# Out:
#           Client Category  mean_of_deal
# 0                Airpline    495206.973
# 1             Automobiles    643664.905
# 2              Consulting   1053182.654
# 3           Consumer Good    737844.197
# 4           Domestic Bank   1672783.143
# 5   Domestic Private Bank    818123.036
# 6    Domestic Public Bank    963349.713
# 7             Electronics    568086.421
# 8                  Energy   1170758.515
# 9                 Energy     751136.725
# 10                Finance    505137.082
# 11                   Govt    793242.586
# 12      Govt Bank Special    536441.893
# 13             Healthcare    440270.351
# 14                Holding   1190247.060
# 15            Hospitality    357174.988
# 16             Industries    465512.478
# 17         Infrastructure    695325.078
# 18              Insurance   1177733.985
# 19               Internal   1019091.553
# 20     International Bank    800162.704
# 21      International Org    796776.471
# ...

# %%
max_deal_year.min()
# Out:
# Client Category     Airpline
# mean_of_deal      111659.664
# dtype: object

# %%
max_deal_year.max()
# Out:
# Client Category    e-commerce
# mean_of_deal      1672783.143
# dtype: object

# %%
#4
win["Client Category"].value_counts()
# Out:
# Others                   1763
# Internal                 1454
# Services_based           1202
# Tech                      913
# Domestic Public Bank      419
# International Bank        376
# Consulting                352
# Finance                   339
# Telecom                   327
# Power ind                 264
# Domestic Private Bank     262
# Insurance                 247
# Consumer Good             185
# Automobiles               178
# Infrastructure            152
# Domestic Bank             134
# Retail_market             126
# Govt                      121
# Hospitality               119
# Manufacturing             117
# Pharma                    110
# Healthcare                 99
# Electronics                81
# Media_Journal              71
# Industries                 66
# Research Development       63
# Energy                     57
# Knowledge                  50
# Management                 43
# Govt Bank Special          41
# Payment                    40
# ...

# %%
win["Deal Status Code_cat"]=win["Deal Status Code"].map({"Won":1, "Lost":0}) 
win.drop(columns=["Deal Status Code"], inplace=True)
win
# Out:
#       Client Category Solution Type  Deal Date     Sector Location  \
# 0             Telecom    Solution 7 2012-03-27  Sector 24       L5
# 1             Telecom    Solution 7 2012-09-25  Sector 24       L5
# 2            Internal   Solution 59 2011-08-01  Sector 20   Others
# 3            Internal   Solution 59 2011-04-28  Sector 20   Others
# 4            Internal   Solution 32 2011-06-03  Sector 20   Others
# ...               ...           ...        ...        ...      ...
# 10056       Power ind    Solution 9 2019-03-18   Sector 9       L5
# 10057        Internal    Solution 6 2019-03-04  Sector 20   Others
# 10058       Power ind    Solution 9 2019-02-28   Sector 9       L5
# 10059       Power ind   Solution 62 2019-01-27   Sector 9       L5
# 10060          Others    Solution 9 2019-05-30  Sector 12      L10
#
#                VP Name     Manager Name   Deal Cost  year  \
# 0          Ekta Zutshi  Gopa Trilochana  150000.000  2012
# ...

# %%
#4 easy way to do
#index=voh sirf particular usko add karke total se divide kareke dedega ,jaise , airplane se lenge uski 0,1 ko add krke krdeag aage
pd.crosstab(win["Client Category"],win["Deal Status Code_cat"],normalize="index")
# Out:
# Deal Status Code_cat      0     1
# Client Category
# Airpline              0.815 0.185
# Automobiles           0.629 0.371
# Consulting            0.517 0.483
# Consumer Good         0.530 0.470
# Domestic Bank         0.582 0.418
# Domestic Private Bank 0.672 0.328
# Domestic Public Bank  0.773 0.227
# Electronics           0.667 0.333
# Energy                0.561 0.439
# Energy                0.757 0.243
# Finance               0.678 0.322
# Govt                  0.711 0.289
# Govt Bank Special     0.780 0.220
# Healthcare            0.687 0.313
# Holding               0.560 0.440
# Hospitality           0.790 0.210
# Industries            0.697 0.303
# Infrastructure        0.579 0.421
# Insurance             0.721 0.279
# Internal              0.477 0.523
# International Bank    0.574 0.426
# International Org     0.880 0.120
# Knowledge             0.720 0.280
# Logistics             0.800 0.200
# Management            0.512 0.488
# Manufacturing         0.684 0.316
# ...

# %%
win["Solution Type"].max()
# Out:
# 'Solution 9'

# %%
pd.crosstab(win["Solution Type"],win["Deal Status Code_cat"])
# Out:
# Deal Status Code_cat     0    1
# Solution Type
# Solution 1               2    3
# Solution 10            690  326
# Solution 11             88   52
# Solution 12            342   98
# Solution 13            214   98
# ...                    ...  ...
# Solution 66              0    1
# Solution 67            408  176
# Solution 7             116   62
# Solution 8             190  184
# Solution 9            1018  400
#
# [67 rows x 2 columns]

# %%
win["Solution Type"] & win(["Deal Date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-83c2e5b0cf79> in <module>
# ----> 1 win["Solution Type"] & win(["Deal Date"])
#
# TypeError: 'DataFrame' object is not callable
